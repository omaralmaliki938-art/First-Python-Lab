# %% [markdown]
# <a href="https://colab.research.google.com/github/omaralmaliki938-art/First-Python-Lab/blob/main/LAB_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("enter your name ")
age=input("enter your age ")
print("hello,my name is",name ,"and i am ",age ,"years old.")
# Out:
# enter your name Omar
# enter your age 19
# hello,my name is Omar and i am  19 years old.

# %%
hours=float1(input("enter the hours of the worked"))
rate=float(input("enter the hourly rate"))
pay=hours*rate
print("weekly pay is :",pay)
# Out:
# enter the hours of the worked12
# enter the hourly rate3
# weekly pay is : 36.0

# %%
age1=int(input("enter the first age"))
age2=int(input("enter the second age"))

if age1 > age2:
    print("The first age is greater ",age1)
elif age1 < age2:
    print("The first age is smaller ",age1)
else:
    print("Both ages are equal.")
# Out:
# enter the first age12
# enter the second age10
# The first age is greater  12

# %%
days = input("Enter a three-letter day abbreviation: ").lower()

if days == "thu" or days == "fri" or days == "sat":
    print("Have a nice weekend!")
else:
    print("Have a productive day!")
# Out:
# Enter a three-letter day abbreviation: Mon
# Have a productive day!

# %%
numbers=int(input("enter a score from 0 to 100:"))
if numbers >= 90 and numbers <= 100:
     print ("a")
elif numbers >= 80 or numbers <= 89:
     print ("b")
elif numbers >= 70 or numbers <= 79:
     print ("c")
elif numbers >= 60 or numbers <= 69:
     print ("d")
# Out:
# enter a score from 0 to 100:77
# b
